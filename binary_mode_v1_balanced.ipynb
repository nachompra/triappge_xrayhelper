# %% [markdown]
# FIRST STEPS

# %%
# Import necessary libraries
from utils import *


# Load datasets
train_images, train_labels = load_dataset_split('data/original/balanced/train')
val_images, val_labels = load_dataset_split('data/original/balanced/val')
test_images, test_labels = load_dataset_split('data/original/balanced/test')

# Create TensorFlow datasets (unchanged)
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# Calculate class weights based on TRAINING SET
class_weights = compute_class_weight('balanced', 
                                   classes=np.unique(train_labels), 
                                   y=train_labels)
class_weight = {0: class_weights[0], 1: class_weights[1]}

# Model definition (unchanged)
model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=(64, 64, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(64, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(128, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(256, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# Compile and train (unchanged)
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy", tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.2, patience=3, min_lr=1e-6
)

history = model.fit(
    train_dataset,
    epochs=10,
    validation_data=val_dataset,
    class_weight=class_weight,
    callbacks=[early_stopping, reduce_lr]
)


test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 123ms/step - accuracy: 0.8910 - auc_1: 0.6468 - loss: 0.3947 - precision_1: 0.9399 - recall_1: 0.9058 - val_accuracy: 0.6337 - val_auc_1: 0.6478 - val_loss: 0.8157 - val_precision_1: 0.5538 - val_recall_1: 0.6131 - learning_rate: 0.0010
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - accuracy: 0.8651 - auc_1: 0.6371 - loss: 0.3571 - precision_1: 0.9471 - recall_1: 0.8764 - val_accuracy: 0.4356 - val_auc_1: 0.6039 - val_loss: 1.2785 - val_precision_1: 0.4206 - val_recall_1: 0.9464 - learning_rate: 0.0010
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 113ms/step - accuracy: 0.8720 - auc_1: 0.6314 - loss: 0.3930 - precision_1: 0.9447 - recall_1: 0.8903 - val_accuracy: 0.6733 - val_auc_1: 0.7992 - val_loss: 1.2405 - val_precision_1: 0.9091 - val_recall_1: 0.2381 - learning_rate: 0.0010
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.8753 - auc_1: 0.6672 - loss: 0.3155 - precision_1: 0.9516 - recall_1: 0.8925 - val_accuracy: 0.7252 - val_auc_1: 0.9600 - val_loss: 0.6233 - val_precision_1: 1.0000 - val_recall_1: 0.3393 - learning_rate: 0.0010
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.8877 - auc_1: 0.6772 - loss: 0.2907 - precision_1: 0.9552 - recall_1: 0.9044 - val_accuracy: 0.8886 - val_auc_1: 0.9983 - val_loss: 0.2156 - val_precision_1: 1.0000 - val_recall_1: 0.7321 - learning_rate: 0.0010
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.9396 - auc_1: 0.7122 - loss: 0.1519 - precision_1: 0.9776 - recall_1: 0.9462 - val_accuracy: 0.9653 - val_auc_1: 0.9994 - val_loss: 0.0857 - val_precision_1: 1.0000 - val_recall_1: 0.9167 - learning_rate: 0.0010
# Epoch 7/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9516 - auc_1: 0.7297 - loss: 0.1178 - precision_1: 0.9844 - recall_1: 0.9556 - val_accuracy: 0.9530 - val_auc_1: 0.9986 - val_loss: 0.1205 - val_precision_1: 1.0000 - val_recall_1: 0.8869 - learning_rate: 0.0010
# Epoch 8/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.9670 - auc_1: 0.7350 - loss: 0.0969 - precision_1: 0.9872 - recall_1: 0.9713 - val_accuracy: 0.9876 - val_auc_1: 0.9993 - val_loss: 0.0449 - val_precision_1: 0.9880 - val_recall_1: 0.9821 - learning_rate: 0.0010
# Epoch 9/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 129ms/step - accuracy: 0.9710 - auc_1: 0.7347 - loss: 0.0901 - precision_1: 0.9870 - recall_1: 0.9766 - val_accuracy: 0.9802 - val_auc_1: 0.9988 - val_loss: 0.0600 - val_precision_1: 1.0000 - val_recall_1: 0.9524 - learning_rate: 0.0010
# Epoch 10/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 130ms/step - accuracy: 0.9740 - auc_1: 0.7422 - loss: 0.0633 - precision_1: 0.9874 - recall_1: 0.9796 - val_accuracy: 0.9901 - val_auc_1: 0.9997 - val_loss: 0.0291 - val_precision_1: 1.0000 - val_recall_1: 0.9762 - learning_rate: 0.0010
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9625 - auc_1: 0.5711 - loss: 0.0766 - precision_1: 0.9981 - recall_1: 0.9508
# Test Accuracy: 0.9674185514450073
# Test Precision: 0.9946808218955994
# Test Recall: 0.9396985173225403
# Test AUC: 0.9990326166152954

# %%
from utils import *
plot_conf_matrix(model, test_images, test_labels)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step

# %%
filename = 'binary_model_v1_balanced.pkl'
create_pkl(filename, model)

# %%
plot_roc_curve(model, test_images, test_labels)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
plot_pr_curve(model, test_images, test_labels)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
p_proba_dist(model, test_images, test_labels)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
show_ten_samples(model, test_images, test_labels)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
loss_accu_train(history)

# %% [markdown]
# Revisando las métricas, vamos a ajustar 7 epochs el modelo.

# %%
history_2 = model.fit(
    train_dataset,
    epochs=7,
    validation_data=val_dataset,
    class_weight=class_weight,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 128ms/step - accuracy: 0.9896 - auc_1: 0.7456 - loss: 0.0313 - precision_1: 0.9962 - recall_1: 0.9903 - val_accuracy: 0.9233 - val_auc_1: 0.9837 - val_loss: 0.2428 - val_precision_1: 1.0000 - val_recall_1: 0.8155 - learning_rate: 0.0010
# Epoch 2/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 16s 121ms/step - accuracy: 0.9875 - auc_1: 0.7298 - loss: 0.0388 - precision_1: 0.9957 - recall_1: 0.9893 - val_accuracy: 0.9431 - val_auc_1: 0.9910 - val_loss: 0.1423 - val_precision_1: 1.0000 - val_recall_1: 0.8631 - learning_rate: 0.0010
# Epoch 3/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 16s 121ms/step - accuracy: 0.9754 - auc_1: 0.7314 - loss: 0.0628 - precision_1: 0.9879 - recall_1: 0.9791 - val_accuracy: 0.8144 - val_auc_1: 0.9108 - val_loss: 0.7986 - val_precision_1: 0.9515 - val_recall_1: 0.5833 - learning_rate: 0.0010
# Epoch 4/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - accuracy: 0.9598 - auc_1: 0.7193 - loss: 0.1217 - precision_1: 0.9793 - recall_1: 0.9681 - val_accuracy: 0.9406 - val_auc_1: 0.9999 - val_loss: 0.1183 - val_precision_1: 1.0000 - val_recall_1: 0.8571 - learning_rate: 0.0010
# Epoch 5/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 118ms/step - accuracy: 0.9710 - auc_1: 0.7298 - loss: 0.0856 - precision_1: 0.9895 - recall_1: 0.9749 - val_accuracy: 0.9802 - val_auc_1: 1.0000 - val_loss: 0.0401 - val_precision_1: 1.0000 - val_recall_1: 0.9524 - learning_rate: 0.0010
# Epoch 6/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 119ms/step - accuracy: 0.9874 - auc_1: 0.7453 - loss: 0.0389 - precision_1: 0.9958 - recall_1: 0.9889 - val_accuracy: 0.9827 - val_auc_1: 0.9936 - val_loss: 0.0783 - val_precision_1: 1.0000 - val_recall_1: 0.9583 - learning_rate: 0.0010
# Epoch 7/7
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 118ms/step - accuracy: 0.9536 - auc_1: 0.7088 - loss: 0.1433 - precision_1: 0.9826 - recall_1: 0.9596 - val_accuracy: 0.9851 - val_auc_1: 0.9980 - val_loss: 0.0478 - val_precision_1: 0.9939 - val_recall_1: 0.9702 - learning_rate: 0.0010

# %%
filename = 'binary_model_v2_balanced.pkl'

create_pkl(filename, model)
