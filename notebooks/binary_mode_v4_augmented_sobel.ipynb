# %% [markdown]
# FIRST STEPS

# %%
from utils import *
# Out:
# WARNING:tensorflow:From c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Cargamos imagenes
train_images_b, train_labels_b = load_dataset_split_sobel('data/original/balanced/train')
val_images_b, val_labels_b = load_dataset_split_sobel('data/original/balanced/val')
test_images_b, test_labels_b = load_dataset_split_sobel('data/original/balanced/test')

train_images_f, train_labels_f = load_dataset_split_sobel('data/augmented/FracAtlas/train')
val_images_f, val_labels_f = load_dataset_split_sobel('data/augmented/FracAtlas/val')
test_images_f, test_labels_f = load_dataset_split_sobel('data/augmented/FracAtlas/test')

train_images = np.concatenate([train_images_b, train_images_f])
train_labels = np.concatenate([train_labels_b, train_labels_f])
test_images = np.concatenate([test_images_b, test_images_f])
test_labels = np.concatenate([test_labels_b, test_labels_f])
val_images = np.concatenate([val_images_b, val_images_f])
val_labels = np.concatenate([val_labels_b, val_labels_f])

# %%
# Creamos Datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
#Calculamos pesos en función del conteo
class_weights = compute_class_weight('balanced', 
                                   classes=np.unique(train_labels), 
                                   y=train_labels)
class_weight = {0: class_weights[0], 1: class_weights[1]}

# %%
model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=(64, 64, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(64, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(128, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(256, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])
# Out:
# WARNING:tensorflow:From c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy", tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.2, patience=3, min_lr=1e-6
)

history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=val_dataset,
    class_weight=class_weight,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# WARNING:tensorflow:From c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 320/320 [==============================] - 52s 121ms/step - loss: 0.3650 - accuracy: 0.8840 - precision: 0.9110 - recall: 0.8699 - auc: 0.9426 - val_loss: 2.3156 - val_accuracy: 0.4889 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6132 - lr: 0.0010
# Epoch 2/50
# 320/320 [==============================] - 47s 147ms/step - loss: 0.4160 - accuracy: 0.8290 - precision: 0.8917 - recall: 0.7774 - auc: 0.9106 - val_loss: 2.3849 - val_accuracy: 0.5077 - val_precision: 0.9583 - val_recall: 0.0385 - val_auc: 0.6994 - lr: 0.0010
# Epoch 3/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.3641 - accuracy: 0.8552 - precision: 0.8858 - recall: 0.8400 - auc: 0.9276 - val_loss: 2.8341 - val_accuracy: 0.4923 - val_precision: 1.0000 - val_recall: 0.0067 - val_auc: 0.6562 - lr: 0.0010
# Epoch 4/50
# 320/320 [==============================] - 46s 145ms/step - loss: 0.3237 - accuracy: 0.8774 - precision: 0.9082 - recall: 0.8598 - auc: 0.9410 - val_loss: 0.7416 - val_accuracy: 0.6410 - val_precision: 0.9045 - val_recall: 0.3328 - val_auc: 0.7755 - lr: 0.0010
# Epoch 5/50
# 320/320 [==============================] - 45s 139ms/step - loss: 0.3101 - accuracy: 0.8804 - precision: 0.9194 - recall: 0.8531 - auc: 0.9484 - val_loss: 0.7931 - val_accuracy: 0.6564 - val_precision: 0.7462 - val_recall: 0.4967 - val_auc: 0.7305 - lr: 0.0010
# Epoch 6/50
# 320/320 [==============================] - 48s 149ms/step - loss: 0.2806 - accuracy: 0.8929 - precision: 0.9225 - recall: 0.8750 - auc: 0.9571 - val_loss: 0.8439 - val_accuracy: 0.6658 - val_precision: 0.6335 - val_recall: 0.8211 - val_auc: 0.7283 - lr: 0.0010
# Epoch 7/50
# 320/320 [==============================] - 46s 145ms/step - loss: 0.2634 - accuracy: 0.9001 - precision: 0.9248 - recall: 0.8870 - auc: 0.9606 - val_loss: 0.9753 - val_accuracy: 0.6556 - val_precision: 0.7876 - val_recall: 0.4465 - val_auc: 0.7537 - lr: 0.0010
# Epoch 8/50
# 320/320 [==============================] - 45s 139ms/step - loss: 0.4185 - accuracy: 0.8178 - precision: 0.8399 - recall: 0.8183 - auc: 0.8955 - val_loss: 0.6959 - val_accuracy: 0.7137 - val_precision: 0.9488 - val_recall: 0.4649 - val_auc: 0.8621 - lr: 2.0000e-04
# Epoch 9/50
# 320/320 [==============================] - 47s 147ms/step - loss: 0.3338 - accuracy: 0.8620 - precision: 0.8735 - recall: 0.8703 - auc: 0.9332 - val_loss: 0.6719 - val_accuracy: 0.7402 - val_precision: 0.9565 - val_recall: 0.5151 - val_auc: 0.8739 - lr: 2.0000e-04
# Epoch 10/50
# 320/320 [==============================] - 47s 147ms/step - loss: 0.2747 - accuracy: 0.8911 - precision: 0.9038 - recall: 0.8933 - auc: 0.9549 - val_loss: 0.7615 - val_accuracy: 0.7436 - val_precision: 0.9382 - val_recall: 0.5334 - val_auc: 0.8422 - lr: 2.0000e-04
# Epoch 11/50
# 320/320 [==============================] - 44s 137ms/step - loss: 0.2178 - accuracy: 0.9182 - precision: 0.9278 - recall: 0.9199 - auc: 0.9714 - val_loss: 0.8067 - val_accuracy: 0.7325 - val_precision: 0.8904 - val_recall: 0.5435 - val_auc: 0.8278 - lr: 2.0000e-04
# Epoch 12/50
# 320/320 [==============================] - 97s 305ms/step - loss: 0.1954 - accuracy: 0.9279 - precision: 0.9302 - recall: 0.9366 - auc: 0.9763 - val_loss: 0.5300 - val_accuracy: 0.7983 - val_precision: 0.9289 - val_recall: 0.6555 - val_auc: 0.8930 - lr: 2.0000e-04
# Epoch 13/50
# 320/320 [==============================] - 82s 255ms/step - loss: 0.1704 - accuracy: 0.9389 - precision: 0.9452 - recall: 0.9413 - auc: 0.9820 - val_loss: 0.5909 - val_accuracy: 0.7923 - val_precision: 0.9810 - val_recall: 0.6054 - val_auc: 0.9151 - lr: 2.0000e-04
# Epoch 14/50
# 320/320 [==============================] - 67s 207ms/step - loss: 0.1445 - accuracy: 0.9446 - precision: 0.9530 - recall: 0.9438 - auc: 0.9870 - val_loss: 0.7290 - val_accuracy: 0.7333 - val_precision: 0.9767 - val_recall: 0.4900 - val_auc: 0.9378 - lr: 2.0000e-04
# Epoch 15/50
# 320/320 [==============================] - 43s 134ms/step - loss: 0.1241 - accuracy: 0.9573 - precision: 0.9617 - recall: 0.9591 - auc: 0.9898 - val_loss: 0.7086 - val_accuracy: 0.7436 - val_precision: 0.9745 - val_recall: 0.5117 - val_auc: 0.9419 - lr: 2.0000e-04
# Epoch 16/50
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2131 - accuracy: 0.9129 - precision: 0.9374 - recall: 0.8986 - auc: 0.9726 - val_loss: 0.3795 - val_accuracy: 0.8470 - val_precision: 0.9505 - val_recall: 0.7391 - val_auc: 0.9485 - lr: 4.0000e-05
# Epoch 17/50
# 320/320 [==============================] - 44s 139ms/step - loss: 0.1741 - accuracy: 0.9342 - precision: 0.9449 - recall: 0.9324 - auc: 0.9820 - val_loss: 0.3257 - val_accuracy: 0.8624 - val_precision: 0.9310 - val_recall: 0.7893 - val_auc: 0.9531 - lr: 4.0000e-05
# Epoch 18/50
# 320/320 [==============================] - 41s 129ms/step - loss: 0.1525 - accuracy: 0.9421 - precision: 0.9536 - recall: 0.9384 - auc: 0.9863 - val_loss: 0.3290 - val_accuracy: 0.8667 - val_precision: 0.9420 - val_recall: 0.7876 - val_auc: 0.9555 - lr: 4.0000e-05
# Epoch 19/50
# 320/320 [==============================] - 46s 145ms/step - loss: 0.1343 - accuracy: 0.9492 - precision: 0.9596 - recall: 0.9457 - auc: 0.9894 - val_loss: 0.2664 - val_accuracy: 0.8838 - val_precision: 0.9358 - val_recall: 0.8294 - val_auc: 0.9635 - lr: 4.0000e-05
# Epoch 20/50
# 320/320 [==============================] - 45s 139ms/step - loss: 0.1174 - accuracy: 0.9583 - precision: 0.9658 - recall: 0.9565 - auc: 0.9921 - val_loss: 0.3118 - val_accuracy: 0.8718 - val_precision: 0.9392 - val_recall: 0.8010 - val_auc: 0.9580 - lr: 4.0000e-05
# Epoch 21/50
# 320/320 [==============================] - 48s 150ms/step - loss: 0.1148 - accuracy: 0.9584 - precision: 0.9699 - recall: 0.9524 - auc: 0.9921 - val_loss: 0.2780 - val_accuracy: 0.8821 - val_precision: 0.9457 - val_recall: 0.8161 - val_auc: 0.9641 - lr: 4.0000e-05
# Epoch 22/50
# 320/320 [==============================] - 43s 135ms/step - loss: 0.1019 - accuracy: 0.9616 - precision: 0.9701 - recall: 0.9583 - auc: 0.9942 - val_loss: 0.2937 - val_accuracy: 0.8812 - val_precision: 0.9509 - val_recall: 0.8094 - val_auc: 0.9621 - lr: 4.0000e-05
# Epoch 23/50
# 320/320 [==============================] - 58s 183ms/step - loss: 0.1129 - accuracy: 0.9559 - precision: 0.9810 - recall: 0.9364 - auc: 0.9930 - val_loss: 0.2509 - val_accuracy: 0.8983 - val_precision: 0.9224 - val_recall: 0.8746 - val_auc: 0.9652 - lr: 8.0000e-06
# Epoch 24/50
# 320/320 [==============================] - 59s 185ms/step - loss: 0.0986 - accuracy: 0.9636 - precision: 0.9797 - recall: 0.9524 - auc: 0.9944 - val_loss: 0.2500 - val_accuracy: 0.8923 - val_precision: 0.8986 - val_recall: 0.8896 - val_auc: 0.9637 - lr: 8.0000e-06
# Epoch 25/50
# 320/320 [==============================] - 46s 143ms/step - loss: 0.0994 - accuracy: 0.9628 - precision: 0.9743 - recall: 0.9562 - auc: 0.9942 - val_loss: 0.2563 - val_accuracy: 0.8915 - val_precision: 0.9026 - val_recall: 0.8829 - val_auc: 0.9626 - lr: 8.0000e-06
# Epoch 26/50
# 320/320 [==============================] - 73s 227ms/step - loss: 0.0923 - accuracy: 0.9667 - precision: 0.9761 - recall: 0.9618 - auc: 0.9953 - val_loss: 0.2607 - val_accuracy: 0.8906 - val_precision: 0.8983 - val_recall: 0.8863 - val_auc: 0.9619 - lr: 8.0000e-06
# Epoch 27/50
# 320/320 [==============================] - 48s 148ms/step - loss: 0.0919 - accuracy: 0.9662 - precision: 0.9775 - recall: 0.9594 - auc: 0.9952 - val_loss: 0.2614 - val_accuracy: 0.8923 - val_precision: 0.8986 - val_recall: 0.8896 - val_auc: 0.9613 - lr: 8.0000e-06
# Epoch 28/50
# 320/320 [==============================] - 56s 175ms/step - loss: 0.0862 - accuracy: 0.9695 - precision: 0.9803 - recall: 0.9629 - auc: 0.9957 - val_loss: 0.2578 - val_accuracy: 0.8906 - val_precision: 0.8943 - val_recall: 0.8913 - val_auc: 0.9620 - lr: 1.6000e-06
# Epoch 29/50
# 320/320 [==============================] - 76s 236ms/step - loss: 0.0859 - accuracy: 0.9683 - precision: 0.9770 - recall: 0.9639 - auc: 0.9960 - val_loss: 0.2528 - val_accuracy: 0.8923 - val_precision: 0.8960 - val_recall: 0.8930 - val_auc: 0.9634 - lr: 1.6000e-06

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 37/37 [==============================] - 4s 97ms/step - loss: 0.3217 - accuracy: 0.8921 - precision: 0.9118 - recall: 0.8857 - auc: 0.9496
# Test Accuracy: 0.892123281955719
# Test Precision: 0.9117646813392639
# Test Recall: 0.8857142925262451
# Test AUC: 0.9495927691459656

# %%
plot_conf_matrix(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 5s 90ms/step

# %%
filename = 'binary_model_v4_1_augmented_sobel.pkl'
create_pkl(filename, model)

# %%
model.save('binary_model_v4_augmented.h5')
# Out:
# c:\Users\Nacho MPra\.conda\envs\fracture_detection\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
plot_roc_curve(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 3s 80ms/step

# %%
plot_pr_curve(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 2s 60ms/step

# %%
p_proba_dist(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 3s 67ms/step

# %%
show_ten_samples(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 3s 77ms/step

# %%
loss_accu_train(history)

# %% [markdown]
# Revisando las métricas, vamos a ajustar 8 epochs el modelo.
