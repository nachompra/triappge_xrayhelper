# %% [markdown]
# FIRST STEPS

# %%
from utils import *
from validation import *


train_images_b, train_labels_b = load_dataset_split('data/original/balanced/train')
val_images_b, val_labels_b = load_dataset_split('data/original/balanced/val')
test_images_b, test_labels_b = load_dataset_split('data/original/balanced/test')

train_images_f, train_labels_f = load_dataset_split('data/augmented/FracAtlas/train')
val_images_f, val_labels_f = load_dataset_split('data/augmented/FracAtlas/val')
test_images_f, test_labels_f = load_dataset_split('data/augmented/FracAtlas/test')

train_images = np.concatenate([train_images_b, train_images_f])
train_labels = np.concatenate([train_labels_b, train_labels_f])
test_images = np.concatenate([test_images_b, test_images_f])
test_labels = np.concatenate([test_labels_b, test_labels_f])
val_images = np.concatenate([val_images_b, val_images_f])
val_labels = np.concatenate([val_labels_b, val_labels_f])

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
class_weights = compute_class_weight('balanced', 
                                   classes=np.unique(train_labels), 
                                   y=train_labels)
class_weight = {0: class_weights[0], 1: class_weights[1]}

# %%
from tensorflow.keras import regularizers
model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=(64, 64, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(64, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(128, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(256, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation="relu",kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy", tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.2, patience=3, min_lr=1e-6
)

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    class_weight=class_weight,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 320/320 [==============================] - 22s 63ms/step - loss: 1.1592 - accuracy: 0.8711 - precision_1: 0.9087 - recall_1: 0.8460 - auc_1: 0.9380 - val_loss: 1.6666 - val_accuracy: 0.4983 - val_precision_1: 0.9231 - val_recall_1: 0.0201 - val_auc_1: 0.6459 - lr: 0.0010
# Epoch 2/100
# 320/320 [==============================] - 20s 64ms/step - loss: 0.5421 - accuracy: 0.8616 - precision_1: 0.8978 - recall_1: 0.8389 - auc_1: 0.9280 - val_loss: 1.6041 - val_accuracy: 0.5060 - val_precision_1: 1.0000 - val_recall_1: 0.0334 - val_auc_1: 0.7681 - lr: 0.0010
# Epoch 3/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.4510 - accuracy: 0.8705 - precision_1: 0.9022 - recall_1: 0.8524 - auc_1: 0.9360 - val_loss: 2.2155 - val_accuracy: 0.4949 - val_precision_1: 1.0000 - val_recall_1: 0.0117 - val_auc_1: 0.7500 - lr: 0.0010
# Epoch 4/100
# 320/320 [==============================] - 20s 62ms/step - loss: 0.4330 - accuracy: 0.8722 - precision_1: 0.9115 - recall_1: 0.8451 - auc_1: 0.9386 - val_loss: 1.6218 - val_accuracy: 0.5308 - val_precision_1: 0.9298 - val_recall_1: 0.0886 - val_auc_1: 0.7571 - lr: 0.0010
# Epoch 5/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.4062 - accuracy: 0.8810 - precision_1: 0.9124 - recall_1: 0.8621 - auc_1: 0.9432 - val_loss: 1.0998 - val_accuracy: 0.5735 - val_precision_1: 0.8153 - val_recall_1: 0.2140 - val_auc_1: 0.7501 - lr: 0.0010
# Epoch 6/100
# 320/320 [==============================] - 20s 63ms/step - loss: 0.4004 - accuracy: 0.8847 - precision_1: 0.9115 - recall_1: 0.8708 - auc_1: 0.9443 - val_loss: 1.3327 - val_accuracy: 0.5675 - val_precision_1: 0.9694 - val_recall_1: 0.1589 - val_auc_1: 0.7892 - lr: 0.0010
# Epoch 7/100
# 320/320 [==============================] - 20s 62ms/step - loss: 0.3618 - accuracy: 0.8965 - precision_1: 0.9195 - recall_1: 0.8857 - auc_1: 0.9535 - val_loss: 1.6297 - val_accuracy: 0.5333 - val_precision_1: 1.0000 - val_recall_1: 0.0870 - val_auc_1: 0.8117 - lr: 0.0010
# Epoch 8/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.3472 - accuracy: 0.8995 - precision_1: 0.9233 - recall_1: 0.8875 - auc_1: 0.9562 - val_loss: 1.3560 - val_accuracy: 0.5179 - val_precision_1: 1.0000 - val_recall_1: 0.0569 - val_auc_1: 0.8003 - lr: 0.0010
# Epoch 9/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.5227 - accuracy: 0.7981 - precision_1: 0.8170 - recall_1: 0.8063 - auc_1: 0.8685 - val_loss: 1.3421 - val_accuracy: 0.5419 - val_precision_1: 0.9844 - val_recall_1: 0.1054 - val_auc_1: 0.8566 - lr: 2.0000e-04
# Epoch 10/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.4041 - accuracy: 0.8507 - precision_1: 0.8708 - recall_1: 0.8495 - auc_1: 0.9234 - val_loss: 1.0660 - val_accuracy: 0.5803 - val_precision_1: 0.9573 - val_recall_1: 0.1873 - val_auc_1: 0.8782 - lr: 2.0000e-04
# Epoch 11/100
# 320/320 [==============================] - 19s 61ms/step - loss: 0.3325 - accuracy: 0.8835 - precision_1: 0.8968 - recall_1: 0.8861 - auc_1: 0.9516 - val_loss: 0.8269 - val_accuracy: 0.6496 - val_precision_1: 0.9608 - val_recall_1: 0.3278 - val_auc_1: 0.8940 - lr: 2.0000e-04
# Epoch 12/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.2679 - accuracy: 0.9168 - precision_1: 0.9242 - recall_1: 0.9214 - auc_1: 0.9711 - val_loss: 0.6691 - val_accuracy: 0.7128 - val_precision_1: 0.8853 - val_recall_1: 0.5033 - val_auc_1: 0.8640 - lr: 2.0000e-04
# Epoch 13/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.2380 - accuracy: 0.9315 - precision_1: 0.9364 - recall_1: 0.9366 - auc_1: 0.9782 - val_loss: 0.7299 - val_accuracy: 0.6855 - val_precision_1: 0.9832 - val_recall_1: 0.3913 - val_auc_1: 0.9146 - lr: 2.0000e-04
# Epoch 14/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.2193 - accuracy: 0.9390 - precision_1: 0.9474 - recall_1: 0.9391 - auc_1: 0.9821 - val_loss: 0.6080 - val_accuracy: 0.7479 - val_precision_1: 0.9220 - val_recall_1: 0.5535 - val_auc_1: 0.8906 - lr: 2.0000e-04
# Epoch 15/100
# 320/320 [==============================] - 18s 57ms/step - loss: 0.1876 - accuracy: 0.9502 - precision_1: 0.9555 - recall_1: 0.9520 - auc_1: 0.9881 - val_loss: 0.5488 - val_accuracy: 0.7752 - val_precision_1: 0.9614 - val_recall_1: 0.5836 - val_auc_1: 0.9194 - lr: 2.0000e-04
# Epoch 16/100
# 320/320 [==============================] - 18s 56ms/step - loss: 0.1655 - accuracy: 0.9594 - precision_1: 0.9645 - recall_1: 0.9601 - auc_1: 0.9909 - val_loss: 0.6644 - val_accuracy: 0.7299 - val_precision_1: 0.9700 - val_recall_1: 0.4866 - val_auc_1: 0.9246 - lr: 2.0000e-04
# Epoch 17/100
# 320/320 [==============================] - 18s 56ms/step - loss: 0.1596 - accuracy: 0.9617 - precision_1: 0.9675 - recall_1: 0.9612 - auc_1: 0.9914 - val_loss: 0.5489 - val_accuracy: 0.7615 - val_precision_1: 0.9650 - val_recall_1: 0.5535 - val_auc_1: 0.9298 - lr: 2.0000e-04
# Epoch 18/100
# 320/320 [==============================] - 18s 56ms/step - loss: 0.1400 - accuracy: 0.9671 - precision_1: 0.9709 - recall_1: 0.9679 - auc_1: 0.9938 - val_loss: 0.5218 - val_accuracy: 0.7897 - val_precision_1: 0.9706 - val_recall_1: 0.6070 - val_auc_1: 0.9509 - lr: 2.0000e-04
# Epoch 19/100
# 320/320 [==============================] - 18s 56ms/step - loss: 0.1280 - accuracy: 0.9710 - precision_1: 0.9763 - recall_1: 0.9697 - auc_1: 0.9951 - val_loss: 0.5522 - val_accuracy: 0.7940 - val_precision_1: 0.9710 - val_recall_1: 0.6154 - val_auc_1: 0.9400 - lr: 2.0000e-04
# Epoch 20/100
# 320/320 [==============================] - 18s 55ms/step - loss: 0.1171 - accuracy: 0.9749 - precision_1: 0.9763 - recall_1: 0.9772 - auc_1: 0.9959 - val_loss: 0.5085 - val_accuracy: 0.8120 - val_precision_1: 0.9437 - val_recall_1: 0.6722 - val_auc_1: 0.9380 - lr: 2.0000e-04
# Epoch 21/100
# 320/320 [==============================] - 18s 55ms/step - loss: 0.1081 - accuracy: 0.9772 - precision_1: 0.9800 - recall_1: 0.9777 - auc_1: 0.9966 - val_loss: 0.5081 - val_accuracy: 0.8274 - val_precision_1: 0.9783 - val_recall_1: 0.6773 - val_auc_1: 0.9576 - lr: 2.0000e-04
# Epoch 22/100
# 320/320 [==============================] - 18s 55ms/step - loss: 0.0963 - accuracy: 0.9798 - precision_1: 0.9847 - recall_1: 0.9777 - auc_1: 0.9978 - val_loss: 0.5388 - val_accuracy: 0.8239 - val_precision_1: 0.9712 - val_recall_1: 0.6756 - val_auc_1: 0.9499 - lr: 2.0000e-04
# Epoch 23/100
# 320/320 [==============================] - 18s 57ms/step - loss: 0.0895 - accuracy: 0.9827 - precision_1: 0.9869 - recall_1: 0.9810 - auc_1: 0.9981 - val_loss: 0.3977 - val_accuracy: 0.8650 - val_precision_1: 0.9527 - val_recall_1: 0.7742 - val_auc_1: 0.9582 - lr: 2.0000e-04
# Epoch 24/100
# 320/320 [==============================] - 18s 56ms/step - loss: 0.0836 - accuracy: 0.9846 - precision_1: 0.9867 - recall_1: 0.9846 - auc_1: 0.9984 - val_loss: 0.3590 - val_accuracy: 0.8684 - val_precision_1: 0.9319 - val_recall_1: 0.8010 - val_auc_1: 0.9624 - lr: 2.0000e-04
# Epoch 25/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.0793 - accuracy: 0.9852 - precision_1: 0.9885 - recall_1: 0.9841 - auc_1: 0.9985 - val_loss: 0.3863 - val_accuracy: 0.8752 - val_precision_1: 0.9650 - val_recall_1: 0.7843 - val_auc_1: 0.9655 - lr: 2.0000e-04
# Epoch 26/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.0726 - accuracy: 0.9889 - precision_1: 0.9916 - recall_1: 0.9877 - auc_1: 0.9986 - val_loss: 0.3972 - val_accuracy: 0.8564 - val_precision_1: 0.9135 - val_recall_1: 0.7943 - val_auc_1: 0.9476 - lr: 2.0000e-04
# Epoch 27/100
# 320/320 [==============================] - 20s 61ms/step - loss: 0.0683 - accuracy: 0.9894 - precision_1: 0.9911 - recall_1: 0.9893 - auc_1: 0.9991 - val_loss: 0.4719 - val_accuracy: 0.8564 - val_precision_1: 0.9694 - val_recall_1: 0.7425 - val_auc_1: 0.9616 - lr: 2.0000e-04
# Epoch 28/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.0975 - accuracy: 0.9759 - precision_1: 0.9833 - recall_1: 0.9717 - auc_1: 0.9974 - val_loss: 0.3016 - val_accuracy: 0.9077 - val_precision_1: 0.9537 - val_recall_1: 0.8612 - val_auc_1: 0.9723 - lr: 4.0000e-05
# Epoch 29/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.0771 - accuracy: 0.9853 - precision_1: 0.9889 - recall_1: 0.9839 - auc_1: 0.9986 - val_loss: 0.2789 - val_accuracy: 0.9120 - val_precision_1: 0.9412 - val_recall_1: 0.8829 - val_auc_1: 0.9737 - lr: 4.0000e-05
# Epoch 30/100
# 320/320 [==============================] - 20s 62ms/step - loss: 0.0656 - accuracy: 0.9893 - precision_1: 0.9918 - recall_1: 0.9884 - auc_1: 0.9993 - val_loss: 0.2656 - val_accuracy: 0.9197 - val_precision_1: 0.9345 - val_recall_1: 0.9064 - val_auc_1: 0.9747 - lr: 4.0000e-05
# Epoch 31/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0624 - accuracy: 0.9915 - precision_1: 0.9944 - recall_1: 0.9899 - auc_1: 0.9994 - val_loss: 0.2748 - val_accuracy: 0.9137 - val_precision_1: 0.9414 - val_recall_1: 0.8863 - val_auc_1: 0.9735 - lr: 4.0000e-05
# Epoch 32/100
# 320/320 [==============================] - 18s 57ms/step - loss: 0.0569 - accuracy: 0.9929 - precision_1: 0.9949 - recall_1: 0.9918 - auc_1: 0.9996 - val_loss: 0.2623 - val_accuracy: 0.9188 - val_precision_1: 0.9374 - val_recall_1: 0.9013 - val_auc_1: 0.9760 - lr: 4.0000e-05
# Epoch 33/100
# 320/320 [==============================] - 18s 57ms/step - loss: 0.0525 - accuracy: 0.9936 - precision_1: 0.9955 - recall_1: 0.9928 - auc_1: 0.9998 - val_loss: 0.2603 - val_accuracy: 0.9179 - val_precision_1: 0.9358 - val_recall_1: 0.9013 - val_auc_1: 0.9756 - lr: 4.0000e-05
# Epoch 34/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0493 - accuracy: 0.9944 - precision_1: 0.9964 - recall_1: 0.9933 - auc_1: 0.9998 - val_loss: 0.2704 - val_accuracy: 0.9120 - val_precision_1: 0.9335 - val_recall_1: 0.8913 - val_auc_1: 0.9749 - lr: 4.0000e-05
# Epoch 35/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0451 - accuracy: 0.9961 - precision_1: 0.9976 - recall_1: 0.9951 - auc_1: 0.9999 - val_loss: 0.2609 - val_accuracy: 0.9145 - val_precision_1: 0.9264 - val_recall_1: 0.9047 - val_auc_1: 0.9756 - lr: 4.0000e-05
# Epoch 36/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.0442 - accuracy: 0.9960 - precision_1: 0.9973 - recall_1: 0.9953 - auc_1: 0.9999 - val_loss: 0.2614 - val_accuracy: 0.9171 - val_precision_1: 0.9341 - val_recall_1: 0.9013 - val_auc_1: 0.9756 - lr: 4.0000e-05
# Epoch 37/100
# 320/320 [==============================] - 20s 61ms/step - loss: 0.0501 - accuracy: 0.9935 - precision_1: 0.9985 - recall_1: 0.9893 - auc_1: 0.9998 - val_loss: 0.2553 - val_accuracy: 0.9120 - val_precision_1: 0.9011 - val_recall_1: 0.9298 - val_auc_1: 0.9748 - lr: 8.0000e-06
# Epoch 38/100
# 320/320 [==============================] - 20s 61ms/step - loss: 0.0420 - accuracy: 0.9969 - precision_1: 0.9985 - recall_1: 0.9957 - auc_1: 0.9999 - val_loss: 0.2577 - val_accuracy: 0.9128 - val_precision_1: 0.9026 - val_recall_1: 0.9298 - val_auc_1: 0.9750 - lr: 8.0000e-06
# Epoch 39/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.0426 - accuracy: 0.9961 - precision_1: 0.9973 - recall_1: 0.9955 - auc_1: 0.9999 - val_loss: 0.2605 - val_accuracy: 0.9128 - val_precision_1: 0.9026 - val_recall_1: 0.9298 - val_auc_1: 0.9748 - lr: 8.0000e-06
# Epoch 40/100
# 320/320 [==============================] - 18s 57ms/step - loss: 0.0421 - accuracy: 0.9965 - precision_1: 0.9984 - recall_1: 0.9951 - auc_1: 0.9999 - val_loss: 0.2633 - val_accuracy: 0.9120 - val_precision_1: 0.8986 - val_recall_1: 0.9331 - val_auc_1: 0.9746 - lr: 8.0000e-06
# Epoch 41/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.0388 - accuracy: 0.9975 - precision_1: 0.9996 - recall_1: 0.9957 - auc_1: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9128 - val_precision_1: 0.8987 - val_recall_1: 0.9348 - val_auc_1: 0.9744 - lr: 1.6000e-06
# Epoch 42/100
# 320/320 [==============================] - 19s 60ms/step - loss: 0.0394 - accuracy: 0.9977 - precision_1: 0.9993 - recall_1: 0.9964 - auc_1: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9128 - val_precision_1: 0.8987 - val_recall_1: 0.9348 - val_auc_1: 0.9738 - lr: 1.6000e-06
# Epoch 43/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0383 - accuracy: 0.9982 - precision_1: 0.9991 - recall_1: 0.9976 - auc_1: 1.0000 - val_loss: 0.2675 - val_accuracy: 0.9137 - val_precision_1: 0.8989 - val_recall_1: 0.9365 - val_auc_1: 0.9736 - lr: 1.6000e-06
# Epoch 44/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0395 - accuracy: 0.9978 - precision_1: 0.9995 - recall_1: 0.9964 - auc_1: 1.0000 - val_loss: 0.2681 - val_accuracy: 0.9128 - val_precision_1: 0.8987 - val_recall_1: 0.9348 - val_auc_1: 0.9734 - lr: 1.0000e-06
# Epoch 45/100
# 320/320 [==============================] - 19s 58ms/step - loss: 0.0410 - accuracy: 0.9961 - precision_1: 0.9989 - recall_1: 0.9938 - auc_1: 0.9999 - val_loss: 0.2683 - val_accuracy: 0.9137 - val_precision_1: 0.8989 - val_recall_1: 0.9365 - val_auc_1: 0.9736 - lr: 1.0000e-06
# Epoch 46/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0398 - accuracy: 0.9973 - precision_1: 0.9987 - recall_1: 0.9962 - auc_1: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9137 - val_precision_1: 0.8989 - val_recall_1: 0.9365 - val_auc_1: 0.9729 - lr: 1.0000e-06
# Epoch 47/100
# 320/320 [==============================] - 19s 59ms/step - loss: 0.0393 - accuracy: 0.9968 - precision_1: 0.9984 - recall_1: 0.9957 - auc_1: 0.9999 - val_loss: 0.2687 - val_accuracy: 0.9128 - val_precision_1: 0.8974 - val_recall_1: 0.9365 - val_auc_1: 0.9722 - lr: 1.0000e-06

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 37/37 [==============================] - 1s 19ms/step - loss: 0.2580 - accuracy: 0.9281 - precision_1: 0.9292 - recall_1: 0.9381 - auc_1: 0.9721
# Test Accuracy: 0.9280821681022644
# Test Precision: 0.9292452931404114
# Test Recall: 0.938095211982727
# Test AUC: 0.9721395969390869

# %%
plot_conf_matrix(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 18ms/step

# %%
filename = 'binary_model_v3_augmented_reg.pkl'
create_pkl(filename, model)

# %%
model.save('binary_model_v3_augmented_reg.keras')

# %%
plot_roc_curve(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 20ms/step

# %%
plot_pr_curve(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 19ms/step

# %%
p_proba_dist(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 19ms/step

# %%
show_ten_samples(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 17ms/step

# %%
loss_accu_train(history)

# %% [markdown]
# Revisando las métricas, vamos a ajustar 8 epochs el modelo.
