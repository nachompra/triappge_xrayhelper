# %% [markdown]
# FIRST STEPS

# %%
from utils import *
from validation import *

train_images_b, train_labels_b = load_dataset_split('data/original/balanced/train')
val_images_b, val_labels_b = load_dataset_split('data/original/balanced/val')
test_images_b, test_labels_b = load_dataset_split('data/original/balanced/test')

train_images_f, train_labels_f = load_dataset_split('data/augmented/FracAtlas/train')
val_images_f, val_labels_f = load_dataset_split('data/augmented/FracAtlas/val')
test_images_f, test_labels_f = load_dataset_split('data/augmented/FracAtlas/test')

train_images = np.concatenate([train_images_b, train_images_f])
train_labels = np.concatenate([train_labels_b, train_labels_f])
test_images = np.concatenate([test_images_b, test_images_f])
test_labels = np.concatenate([test_labels_b, test_labels_f])
val_images = np.concatenate([val_images_b, val_images_f])
val_labels = np.concatenate([val_labels_b, val_labels_f])

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
class_weights = compute_class_weight('balanced', 
                                   classes=np.unique(train_labels), 
                                   y=train_labels)
class_weight = {0: class_weights[0], 1: class_weights[1]}

# %%
from tensorflow.keras import regularizers
model = keras.Sequential([
    layers.Conv2D(256, (3, 3), activation="relu", input_shape=(64, 64, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(128, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(64, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(32, (3, 3), activation="relu"),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation="relu",kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy", tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.2, patience=3, min_lr=1e-6
)

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=val_dataset,
    class_weight=class_weight,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 320/320 [==============================] - 107s 325ms/step - loss: 0.9338 - accuracy: 0.8604 - precision_1: 0.8985 - recall_1: 0.8357 - auc_1: 0.9283 - val_loss: 1.5499 - val_accuracy: 0.4889 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.6791 - lr: 0.0010
# Epoch 2/100
# 320/320 [==============================] - 102s 318ms/step - loss: 0.5622 - accuracy: 0.8454 - precision_1: 0.8861 - recall_1: 0.8187 - auc_1: 0.9120 - val_loss: 0.8101 - val_accuracy: 0.5795 - val_precision_1: 0.6879 - val_recall_1: 0.3244 - val_auc_1: 0.6692 - lr: 0.0010
# Epoch 3/100
# 320/320 [==============================] - 102s 319ms/step - loss: 0.5196 - accuracy: 0.8229 - precision_1: 0.8507 - recall_1: 0.8147 - auc_1: 0.8908 - val_loss: 1.7506 - val_accuracy: 0.5051 - val_precision_1: 1.0000 - val_recall_1: 0.0318 - val_auc_1: 0.7707 - lr: 0.0010
# Epoch 4/100
# 320/320 [==============================] - 101s 315ms/step - loss: 0.4265 - accuracy: 0.8494 - precision_1: 0.8870 - recall_1: 0.8261 - auc_1: 0.9174 - val_loss: 0.7849 - val_accuracy: 0.5308 - val_precision_1: 0.5352 - val_recall_1: 0.6237 - val_auc_1: 0.5728 - lr: 0.0010
# Epoch 5/100
# 320/320 [==============================] - 99s 310ms/step - loss: 0.4098 - accuracy: 0.8629 - precision_1: 0.8866 - recall_1: 0.8553 - auc_1: 0.9241 - val_loss: 2.9314 - val_accuracy: 0.4974 - val_precision_1: 1.0000 - val_recall_1: 0.0167 - val_auc_1: 0.6799 - lr: 0.0010
# Epoch 6/100
# 320/320 [==============================] - 98s 307ms/step - loss: 0.3832 - accuracy: 0.8682 - precision_1: 0.8952 - recall_1: 0.8560 - auc_1: 0.9319 - val_loss: 1.7029 - val_accuracy: 0.5248 - val_precision_1: 0.9773 - val_recall_1: 0.0719 - val_auc_1: 0.7547 - lr: 0.0010
# Epoch 7/100
# 320/320 [==============================] - 98s 307ms/step - loss: 0.3925 - accuracy: 0.8643 - precision_1: 0.8956 - recall_1: 0.8473 - auc_1: 0.9281 - val_loss: 1.4888 - val_accuracy: 0.5197 - val_precision_1: 0.9500 - val_recall_1: 0.0635 - val_auc_1: 0.7329 - lr: 0.0010
# Epoch 8/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.5280 - accuracy: 0.7730 - precision_1: 0.8093 - recall_1: 0.7580 - auc_1: 0.8484 - val_loss: 1.0295 - val_accuracy: 0.5487 - val_precision_1: 0.9487 - val_recall_1: 0.1237 - val_auc_1: 0.7389 - lr: 2.0000e-04
# Epoch 9/100
# 320/320 [==============================] - 101s 316ms/step - loss: 0.4452 - accuracy: 0.8158 - precision_1: 0.8484 - recall_1: 0.8018 - auc_1: 0.8962 - val_loss: 0.8407 - val_accuracy: 0.6034 - val_precision_1: 0.9136 - val_recall_1: 0.2475 - val_auc_1: 0.7906 - lr: 2.0000e-04
# Epoch 10/100
# 320/320 [==============================] - 102s 319ms/step - loss: 0.4149 - accuracy: 0.8355 - precision_1: 0.8517 - recall_1: 0.8417 - auc_1: 0.9103 - val_loss: 0.7374 - val_accuracy: 0.6188 - val_precision_1: 0.8455 - val_recall_1: 0.3110 - val_auc_1: 0.7966 - lr: 2.0000e-04
# Epoch 11/100
# 320/320 [==============================] - 101s 317ms/step - loss: 0.3707 - accuracy: 0.8611 - precision_1: 0.8785 - recall_1: 0.8618 - auc_1: 0.9318 - val_loss: 0.6611 - val_accuracy: 0.6769 - val_precision_1: 0.8667 - val_recall_1: 0.4348 - val_auc_1: 0.8199 - lr: 2.0000e-04
# Epoch 12/100
# 320/320 [==============================] - 100s 312ms/step - loss: 0.3313 - accuracy: 0.8811 - precision_1: 0.8933 - recall_1: 0.8855 - auc_1: 0.9476 - val_loss: 0.7417 - val_accuracy: 0.6718 - val_precision_1: 0.8849 - val_recall_1: 0.4114 - val_auc_1: 0.8303 - lr: 2.0000e-04
# Epoch 13/100
# 320/320 [==============================] - 100s 312ms/step - loss: 0.2928 - accuracy: 0.8992 - precision_1: 0.9119 - recall_1: 0.9002 - auc_1: 0.9607 - val_loss: 0.9249 - val_accuracy: 0.6410 - val_precision_1: 0.9363 - val_recall_1: 0.3194 - val_auc_1: 0.8403 - lr: 2.0000e-04
# Epoch 14/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2742 - accuracy: 0.9093 - precision_1: 0.9219 - recall_1: 0.9089 - auc_1: 0.9656 - val_loss: 1.0651 - val_accuracy: 0.5991 - val_precision_1: 0.9057 - val_recall_1: 0.2408 - val_auc_1: 0.7750 - lr: 2.0000e-04
# Epoch 15/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.4211 - accuracy: 0.8237 - precision_1: 0.8672 - recall_1: 0.7949 - auc_1: 0.9080 - val_loss: 0.7184 - val_accuracy: 0.6829 - val_precision_1: 0.9486 - val_recall_1: 0.4013 - val_auc_1: 0.8639 - lr: 4.0000e-05
# Epoch 16/100
# 320/320 [==============================] - 100s 312ms/step - loss: 0.3692 - accuracy: 0.8588 - precision_1: 0.8871 - recall_1: 0.8458 - auc_1: 0.9319 - val_loss: 0.6583 - val_accuracy: 0.7026 - val_precision_1: 0.9596 - val_recall_1: 0.4365 - val_auc_1: 0.8902 - lr: 4.0000e-05
# Epoch 17/100
# 320/320 [==============================] - 100s 312ms/step - loss: 0.3456 - accuracy: 0.8650 - precision_1: 0.8949 - recall_1: 0.8496 - auc_1: 0.9419 - val_loss: 0.5390 - val_accuracy: 0.7530 - val_precision_1: 0.9478 - val_recall_1: 0.5468 - val_auc_1: 0.9120 - lr: 4.0000e-05
# Epoch 18/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.3273 - accuracy: 0.8745 - precision_1: 0.9008 - recall_1: 0.8623 - auc_1: 0.9491 - val_loss: 0.5182 - val_accuracy: 0.7573 - val_precision_1: 0.9486 - val_recall_1: 0.5552 - val_auc_1: 0.9189 - lr: 4.0000e-05
# Epoch 19/100
# 320/320 [==============================] - 100s 312ms/step - loss: 0.3143 - accuracy: 0.8849 - precision_1: 0.9115 - recall_1: 0.8712 - auc_1: 0.9539 - val_loss: 0.5025 - val_accuracy: 0.7701 - val_precision_1: 0.9410 - val_recall_1: 0.5870 - val_auc_1: 0.9234 - lr: 4.0000e-05
# Epoch 20/100
# 320/320 [==============================] - 101s 315ms/step - loss: 0.3082 - accuracy: 0.8872 - precision_1: 0.9128 - recall_1: 0.8745 - auc_1: 0.9556 - val_loss: 0.4552 - val_accuracy: 0.8043 - val_precision_1: 0.9382 - val_recall_1: 0.6605 - val_auc_1: 0.9244 - lr: 4.0000e-05
# Epoch 21/100
# 320/320 [==============================] - 100s 314ms/step - loss: 0.2931 - accuracy: 0.8910 - precision_1: 0.9179 - recall_1: 0.8764 - auc_1: 0.9609 - val_loss: 0.3973 - val_accuracy: 0.8453 - val_precision_1: 0.9427 - val_recall_1: 0.7425 - val_auc_1: 0.9348 - lr: 4.0000e-05
# Epoch 22/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2704 - accuracy: 0.9061 - precision_1: 0.9274 - recall_1: 0.8960 - auc_1: 0.9684 - val_loss: 0.4128 - val_accuracy: 0.8342 - val_precision_1: 0.9391 - val_recall_1: 0.7224 - val_auc_1: 0.9320 - lr: 4.0000e-05
# Epoch 23/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2602 - accuracy: 0.9100 - precision_1: 0.9333 - recall_1: 0.8973 - auc_1: 0.9711 - val_loss: 0.4188 - val_accuracy: 0.8239 - val_precision_1: 0.9336 - val_recall_1: 0.7057 - val_auc_1: 0.9313 - lr: 4.0000e-05
# Epoch 24/100
# 320/320 [==============================] - 101s 315ms/step - loss: 0.2560 - accuracy: 0.9113 - precision_1: 0.9310 - recall_1: 0.9024 - auc_1: 0.9716 - val_loss: 0.4086 - val_accuracy: 0.8419 - val_precision_1: 0.9223 - val_recall_1: 0.7542 - val_auc_1: 0.9306 - lr: 4.0000e-05
# Epoch 25/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2690 - accuracy: 0.9037 - precision_1: 0.9532 - recall_1: 0.8639 - auc_1: 0.9696 - val_loss: 0.4018 - val_accuracy: 0.8504 - val_precision_1: 0.9256 - val_recall_1: 0.7692 - val_auc_1: 0.9323 - lr: 8.0000e-06
# Epoch 26/100
# 320/320 [==============================] - 101s 315ms/step - loss: 0.2520 - accuracy: 0.9130 - precision_1: 0.9488 - recall_1: 0.8866 - auc_1: 0.9735 - val_loss: 0.3949 - val_accuracy: 0.8521 - val_precision_1: 0.9175 - val_recall_1: 0.7809 - val_auc_1: 0.9316 - lr: 8.0000e-06
# Epoch 27/100
# 320/320 [==============================] - 101s 314ms/step - loss: 0.2493 - accuracy: 0.9140 - precision_1: 0.9441 - recall_1: 0.8935 - auc_1: 0.9739 - val_loss: 0.3913 - val_accuracy: 0.8547 - val_precision_1: 0.9115 - val_recall_1: 0.7926 - val_auc_1: 0.9313 - lr: 8.0000e-06
# Epoch 28/100
# 320/320 [==============================] - 101s 316ms/step - loss: 0.2434 - accuracy: 0.9180 - precision_1: 0.9454 - recall_1: 0.9000 - auc_1: 0.9755 - val_loss: 0.3884 - val_accuracy: 0.8538 - val_precision_1: 0.9114 - val_recall_1: 0.7910 - val_auc_1: 0.9323 - lr: 8.0000e-06
# Epoch 29/100
# 320/320 [==============================] - 101s 315ms/step - loss: 0.2365 - accuracy: 0.9196 - precision_1: 0.9456 - recall_1: 0.9029 - auc_1: 0.9774 - val_loss: 0.3807 - val_accuracy: 0.8590 - val_precision_1: 0.9124 - val_recall_1: 0.8010 - val_auc_1: 0.9336 - lr: 8.0000e-06
# Epoch 30/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2327 - accuracy: 0.9234 - precision_1: 0.9439 - recall_1: 0.9121 - auc_1: 0.9782 - val_loss: 0.3864 - val_accuracy: 0.8556 - val_precision_1: 0.9149 - val_recall_1: 0.7910 - val_auc_1: 0.9329 - lr: 8.0000e-06
# Epoch 31/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2299 - accuracy: 0.9242 - precision_1: 0.9499 - recall_1: 0.9074 - auc_1: 0.9790 - val_loss: 0.3841 - val_accuracy: 0.8573 - val_precision_1: 0.9136 - val_recall_1: 0.7960 - val_auc_1: 0.9340 - lr: 8.0000e-06
# Epoch 32/100
# 320/320 [==============================] - 101s 317ms/step - loss: 0.2295 - accuracy: 0.9240 - precision_1: 0.9485 - recall_1: 0.9083 - auc_1: 0.9789 - val_loss: 0.3777 - val_accuracy: 0.8615 - val_precision_1: 0.9113 - val_recall_1: 0.8077 - val_auc_1: 0.9353 - lr: 8.0000e-06
# Epoch 33/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2268 - accuracy: 0.9253 - precision_1: 0.9490 - recall_1: 0.9105 - auc_1: 0.9797 - val_loss: 0.3786 - val_accuracy: 0.8564 - val_precision_1: 0.9072 - val_recall_1: 0.8010 - val_auc_1: 0.9349 - lr: 8.0000e-06
# Epoch 34/100
# 320/320 [==============================] - 100s 313ms/step - loss: 0.2261 - accuracy: 0.9250 - precision_1: 0.9460 - recall_1: 0.9132 - auc_1: 0.9796 - val_loss: 0.3843 - val_accuracy: 0.8598 - val_precision_1: 0.9094 - val_recall_1: 0.8060 - val_auc_1: 0.9336 - lr: 8.0000e-06
# Epoch 35/100
# 320/320 [==============================] - 103s 321ms/step - loss: 0.2160 - accuracy: 0.9319 - precision_1: 0.9529 - recall_1: 0.9192 - auc_1: 0.9823 - val_loss: 0.3863 - val_accuracy: 0.8556 - val_precision_1: 0.9101 - val_recall_1: 0.7960 - val_auc_1: 0.9337 - lr: 8.0000e-06
# Epoch 36/100
# 320/320 [==============================] - 102s 317ms/step - loss: 0.2186 - accuracy: 0.9293 - precision_1: 0.9589 - recall_1: 0.9080 - auc_1: 0.9815 - val_loss: 0.3880 - val_accuracy: 0.8530 - val_precision_1: 0.9096 - val_recall_1: 0.7910 - val_auc_1: 0.9336 - lr: 1.6000e-06
# Epoch 37/100
# 320/320 [==============================] - 102s 319ms/step - loss: 0.2134 - accuracy: 0.9304 - precision_1: 0.9597 - recall_1: 0.9092 - auc_1: 0.9826 - val_loss: 0.3868 - val_accuracy: 0.8530 - val_precision_1: 0.9096 - val_recall_1: 0.7910 - val_auc_1: 0.9336 - lr: 1.6000e-06
# Epoch 38/100
# 320/320 [==============================] - 101s 314ms/step - loss: 0.2154 - accuracy: 0.9303 - precision_1: 0.9546 - recall_1: 0.9143 - auc_1: 0.9820 - val_loss: 0.3845 - val_accuracy: 0.8556 - val_precision_1: 0.9101 - val_recall_1: 0.7960 - val_auc_1: 0.9338 - lr: 1.6000e-06
# Epoch 39/100
# 320/320 [==============================] - 101s 315ms/step - loss: 0.2140 - accuracy: 0.9333 - precision_1: 0.9581 - recall_1: 0.9165 - auc_1: 0.9825 - val_loss: 0.3843 - val_accuracy: 0.8547 - val_precision_1: 0.9100 - val_recall_1: 0.7943 - val_auc_1: 0.9338 - lr: 1.0000e-06
# Epoch 40/100
# 320/320 [==============================] - 103s 320ms/step - loss: 0.2122 - accuracy: 0.9343 - precision_1: 0.9574 - recall_1: 0.9192 - auc_1: 0.9827 - val_loss: 0.3842 - val_accuracy: 0.8556 - val_precision_1: 0.9101 - val_recall_1: 0.7960 - val_auc_1: 0.9337 - lr: 1.0000e-06
# Epoch 41/100
# 320/320 [==============================] - 100s 314ms/step - loss: 0.2161 - accuracy: 0.9323 - precision_1: 0.9574 - recall_1: 0.9152 - auc_1: 0.9816 - val_loss: 0.3845 - val_accuracy: 0.8564 - val_precision_1: 0.9119 - val_recall_1: 0.7960 - val_auc_1: 0.9337 - lr: 1.0000e-06
# Epoch 42/100
# 320/320 [==============================] - 101s 314ms/step - loss: 0.2138 - accuracy: 0.9321 - precision_1: 0.9561 - recall_1: 0.9161 - auc_1: 0.9824 - val_loss: 0.3826 - val_accuracy: 0.8564 - val_precision_1: 0.9103 - val_recall_1: 0.7977 - val_auc_1: 0.9339 - lr: 1.0000e-06

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 37/37 [==============================] - 4s 95ms/step - loss: 0.4293 - accuracy: 0.8399 - precision_1: 0.8948 - recall_1: 0.7968 - auc_1: 0.9162
# Test Accuracy: 0.8398972749710083
# Test Precision: 0.8948306441307068
# Test Recall: 0.7968254089355469
# Test AUC: 0.9161754250526428

# %%
plot_conf_matrix(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 4s 92ms/step

# %%
filename = 'binary_model_v3_augmented_reg_conv.pkl'
create_pkl(filename, model)

# %%
model.save('binary_model_v3_augmented_reg_conv.keras')

# %%
plot_roc_curve(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 3s 93ms/step

# %%
plot_pr_curve(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 4s 105ms/step

# %%
p_proba_dist(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 4s 100ms/step

# %%
show_ten_samples(model, test_images, test_labels)
# Out:
# 37/37 [==============================] - 4s 95ms/step

# %%
loss_accu_train(history)

# %% [markdown]
# Revisando las métricas, vamos a ajustar 8 epochs el modelo.
