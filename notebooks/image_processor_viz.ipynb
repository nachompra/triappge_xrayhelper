# %%
from utils import *

# %%
train_images_s, train_labels_s = load_dataset_split_sobel('data/original/balanced/train')

# %%
train_images_c, train_labels_c = load_dataset_split_sobel_v4('data/original/balanced/train')

# %%
plt.figure(figsize=(10, 5))
#

#plt.subplot(1, 2, 2)
plt.imshow(train_images_c[1500], cmap='gray')
plt.title("Detección de Edges v2")
plt.axis('off')

plt.show()
